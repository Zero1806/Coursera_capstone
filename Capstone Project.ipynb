# %% [markdown]
# Hello!
# This is a Jupyter notebook that will be used for a Capstone project on Severity of Accidents in Seattle. Here we will deal with a data that was provided by Seattle Police Department and Recorded by Traffic Records.

# %% [markdown]
# The Timeframe of data is from 2004 to present and the data base is updated regularly every week. This ensures us that the machine learning model which will be made will have ample of data to train and test on and will have high out of data accuracy.

# %%
import pandas as pd
import numpy as np
print("The Libraries are loaded")
# Out:
# The Libraries are loaded

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
